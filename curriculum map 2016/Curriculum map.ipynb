# %% [markdown]
# This notebook contains code that will let you examine the curriculum through a very elementary text mining approach. All mineable teaching documents have been downloaded and the readable content extracted. These include word (.docx), powerpoint (.pptx), text, web pages, and PDFs. There are some technical wrinkles, especially with PDFs.
# Keywords and keyword pairs (bigrams) have been extracted from this text and are used as the basis for similarity matching.
# There is the option to use *stemming* in processing the keywords, where plurals and similar derivatives are reduced to just the stem of the word.
#
# Each document is matched against each other document using cosine similarity across the tf-idf metric ( [See the wikipedia entry here](https://en.wikipedia.org/wiki/Tf%E2%80%93idf) ) calculated for every keyword. The score calculated is scaled up by 1 million times larger to give a more readable number. That means about 500,000 document similarity measures. We can use various tools to access the text - finding where particular keywords are (concordance), finding which documents match a document of interest and so on.
#
# The similarity network can be downloaded and run in R to visualise it. If you filter the similarities by score (approximately 2 -3 edges per node is a good rule of thumb) then a clearer representation can be seen. [An R script that does this is available (depends on the igraph package which can be installed from CPAN).](quickview.R)
#
# [A blog post covering text mining and more in R](https://www.r-bloggers.com/an-overview-of-text-mining-visualisations-possibilities-with-r-on-the-ceta-trade-agreement/)

# %% [markdown]
# ## Loading the corpus
# A corpus is a collection of documents. The extracted text is in the *keydata* directory.
#
# Click on the cell below and press CTRL-Enter to run. It could take some time to load (a few minutes). In the example below we use a stemmer from the Natural Language Tool Kit and choose to include pairs of words as keywords.

# %%
import nltk
from tfidf import *
corpus = TeachingCorpus('keydata5', stemmer=nltk.PorterStemmer(), bigraph=True)
# Out:
# Error reading corpus from keydata5: None
# Traceback (most recent call last):
#   File "C:\Users\marti\Documents\LifeSciteaching\Curriculum\curriculumTools\curriculum map 2016\tfidf.py", line 522, in load_corpus
#     corpus = nltk.corpus.PlaintextCorpusReader(self._datadir,'.*\.txt')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\reader\plaintext.py", line 62, in __init__
#     CorpusReader.__init__(self, root, fileids, encoding)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\reader\api.py", line 80, in __init__
#     root = FileSystemPathPointer(root)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\nltk\compat.py", line 41, in _decorator
#     return init_func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py", line 312, in __init__
#     raise OSError("No such file or directory: %r" % _path)
# OSError: No such file or directory: 'C:\\Users\\marti\\Documents\\LifeSciteaching\\Curriculum\\curriculumTools\\curriculum map 2016\\keydata5'

# %%
for f in corpus.corpus.fileids():
    try:
        corpus.indices[f] = IndexedText( corpus._stemmer, corpus.corpus.words(f))
    except: 
        pass

# %% [markdown]
# That has loaded the text and built indexed keyword lists. It is now possible to find keywords throughout the curriculum with the *corpus.show_matches(keyword)* command. To see specific matches, add the option lines=True to the command

# %%
corpus.show_matches('kinase', details=False)
# change the keyword to anything you want and try it out - remember that text must be between quotes.
# Out:
# 351 documents returned matches
# BS42019 (30 files match)
# BS32006 (27 files match)
# BS42013 (24 files match)
# BS42014 (21 files match)
# BS42015 (18 files match)
# BS32009 (12 files match)
# BS31004 (11 files match)
# BS42021 (11 files match)
# BS32003 (11 files match)
# BS42020 (10 files match)
# BS42018 (10 files match)
# BS31005 (10 files match)
# BS42007 (9 files match)
# BS42008 (9 files match)
# BS42005 (8 files match)
# BS42009 (8 files match)
# BS42006 (8 files match)
# BS31006 (8 files match)
# BS32028 (8 files match)
# BS42022 (7 files match)
# BS31019 (7 files match)
# BS42023 (7 files match)
# BS22002 (7 files match)
# BS32004 (6 files match)
# BS42004 (6 files match)
# BS32008 (6 files match)
# BS42024 (6 files match)
# BS31013 (5 files match)
# BS22001 (5 files match)
# BS42010 (4 files match)
# BS21002 (4 files match)
# BS42012 (4 files match)
# BS32024 (3 files match)
# BS42025 (3 files match)
# BS32022 (2 files match)
# advhigher (2 files match)
# BS32011 (2 files match)
# BS31016 (2 files match)
# BS12002 (2 files match)
# BS42017 (1 files match)
# aqa_alevel (1 files match)
# BS32005 (1 files match)
# BS31020 (1 files match)
# BS21003 (1 files match)
# BS32020 (1 files match)
# BS32012 (1 files match)
# BS32026 (1 files match)

# %%
corpus.show_matches('handbook', details=True) 
# this will show the specific matches in context. Note that the text shown in the 
#matches is the stemmed keywords without stopwords so may appear a little strange

# %% [markdown]
# ## Inexact matching of documents and text
#
# Individual keywords are great for some purposes, but can be very noisy. Often we'd like to take a lecture, or a paper and find the most related documents (and hence perhaps the most related module). We can do that by using a measure of how well matched the terms used are weighted by how specific those terms are to a particular document.

# %%
# This is a student essay in a fourth year module.
corpus.match_file('test_document1.docx')
# only the top matches are returned - control the number with the matches option

# %% [markdown]
# We can compare all the files from one module against all the other files not in that module to see how modules relate. This can take some time.

# %%
corpus.match_module('BS31005', matches=10)
# Out:
# Your file Tutorial 3 – Andy Flavell.docx from assessments matched the following modules/documents:
# 55533	BS32008	assessments	BS32008_3.txt	Tutorial 1 Andy Flavell.docx
# 18059	BS32008	week 20	BS32008_7.txt	Lecture 4 - 2016(2).pptx
# 3654	BS32008	assessments	BS32008_1.txt	BS32008 Final 2015.docx
# 3120	BS11001	WEEK 11	BS11001_5.txt	BS11001_LTEY_DZB_molecular_evolution(4).pptx
# 2273	BS22002	week 23	BS22002_25.txt	BS22002Intro(1).pptx
# 2230	BS32022	week 19	BS32022_14.txt	BS32022-L14.pptx
# 1814	BS32008	week 20	BS32008_6.txt	Lecture 3 - 2016.pptx
# 1782	BS12001	week 16	BS12001_5.txt	BS12001 Chromosome structure(1).pptx
# 1706	BS42014	lectures	BS42014_21.txt	L4 2016 Obesity and Metabolic Disease Lectures 5 & 6 (Ashford).pptx
# 1621	BS42008	assessments	BS42008_2.txt	Paper analysis test-Formative.docx
#
# Your file linkage_Tutorial_ notes2015.pptx from assessments matched the following modules/documents:
# 67035	BS12001	week 16	BS12001_6.txt	BS12001 Meiosis and Mendel(2).pptx
# 18956	BS42024	workshops	BS42024_14.txt	Controlled Coursework Question for Practice.docx
# 17417	BS42005	lectures	BS42005_18.txt	Lecture 11 Year 4 McKim.pptx
# 16624	BS42003	week 19	BS42003_18.txt	Linkage_background.pptx
# 8100	BS42005	lectures	BS42005_20.txt	lecture 15.pptx
# 5777	BS42005	lectures	BS42005_27.txt	PNAS-2007-Komatsuda.pdf
# 4823	BS21002	week 10	BS21002_5.txt	genes inheritance and meiosis handout.pptx
# 4514	BS42003	week 19	BS42003_17.txt	Linkage&QTL_mapping.pptx
# 4326	BS42003	week 19	BS42003_14.txt	anthocyaninless paper for class.pdf
# 3669	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
#
# Your file BS31005 Final 2014.docx from assessments matched the following modules/documents:
# 30447	BS32008	assessments	BS32008_1.txt	BS32008 Final 2015.docx
# 15386	BS32008	week 20	BS32008_7.txt	Lecture 4 - 2016(2).pptx
# 5879	BS11001	WEEK 7	BS11001_15.txt	BS11001_Pop genetics(1).pptx
# 5785	BS11001	WEEK 8	BS11001_16.txt	BS11001_Pop genetics.pptx
# 5178	BS32024	assessments	BS32024_10.txt	Paper 7- CW003- GABA-B in anxiety & depression.pdf
# 5099	BS32024	week 24	BS32024_19.txt	DSI explanation.pptx
# 4981	BS42005	lectures	BS42005_25.txt	nrg3291[2] copy.pdf
# 4139	BS32006	general	BS32006_10.txt	CM BS32006 Learning Objectives 2016.docx
# 4137	BS42005	lectures	BS42005_31.txt	Simpson Honours 2015 flowering part one(1).pptx
# 3771	BS32008	assessments	BS32008_3.txt	Tutorial 1 Andy Flavell.docx
#
# Your file additional notes of tutorial.pptx from assessments matched the following modules/documents:
# 7372	BS42003	week 16	BS42003_5.txt	BS42003_Population_genomics.pptx
# 6016	ocr_alevel	skills	ocr_alevel_49.txt	168829-the-ocr-guide-to-presentation-skills.pdf
# 4940	BS42003	week 19	BS42003_21.txt	Yan_Maize_CrtRB1_ng.551.pdf
# 3568	BS21001	week 8	BS21001_15.txt	BS21001 Comparing Analysis of Variance ANOVA.pptx
# 3336	aqa_alevel	curriculum	aqa_alevel_17.txt	AQA-7407-7408-PHBK.DOCX
# 3271	BS42024	workshops	BS42024_25.txt	Possible CCW Answers(1).docx
# 3039	BS32020	week 21	BS32020_4.txt	BS32020_2Transport of O2 and CO2 in blood.pptx
# 2768	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 2157	BS22001	week 24	BS22001_29.txt	BS22001 Transport of O2 and CO2 in blood.pptx
# 1751	BS21001	week 9	BS21001_16.txt	BS21001 Comparing Analysis of Variance ANOVA(1).pptx
#
# Your file Phylogenetic Analysis of Guinea 2014 EBOV Ebolavirus Outbreak – PLOS Currents Outbreaks.html from assessments matched the following modules/documents:
# 8099	BS22002	week 23	BS22002_26.txt	Emerging viruses.pptx
# 3295	BS42003	week 16	BS42003_8.txt	Perelman et al 2011 journal.pgen.1001342.pdf
# 2386	BS42014	lectures	BS42014_26.txt	mTORC1 signalling.pdf
# 2385	BS42013	lectures	BS42013_5.txt	BS42013_CMacK_Reading_list_L3&L4.docx
# 1825	BS42006	week 20	BS42006_17.txt	Matthews Lecture 2.pptx
# 1544	BS11001	WEEK 10	BS11001_4.txt	BS11002_DZB_EvolutionI&II(1).pptx
# 1471	BS11001	WEEK 9	BS11001_17.txt	BS11001_DZB_EvolutionI II III.pptx
# 1286	BS42012	lectures	BS42012_4.txt	BS42012 reading list.pdf
# 1239	BS21002	week 9	BS21002_20.txt	BS21001_JZ_When it goes wrong 1 2015-16(1).pptx
# 1114	BS11001	WORKSHOPS	BS11001_20.txt	PLOS Biology_ Evolutionary Biology for the 21st Century.html
#
# Your file genetic Markers_September 2015.pptx from week 1 matched the following modules/documents:
# 6632	BS42005	lectures	BS42005_10.txt	Ingo Tutorial BS42005 2016.pptx
# 6286	BS32010	assessments	BS32010_2.txt	Assessments – BS32010 - Bioinformatics (15_16).html
# 6286	BS32010	assessments	BS32010_1.txt	Assessments – BS32010 - Bioinformatics (15_16) 1.html
# 3205	BS32008	week 20	BS32008_8.txt	Lecture 5- 2016.pptx
# 2785	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 2772	BS31019	week 4	BS31019_11.txt	Diabetes treatments Lecture 16(1).pptx
# 2503	BS42017	workshops	BS42017_15.txt	BS42017_Essay_Friday_18th_March.pdf
# 2435	BS42005	lectures	BS42005_7.txt	comadran - CEN.pdf
# 2357	BS11002	week 3	BS11002_10.txt	BS11002 The Eukaryotes.pptx
# 2210	BS42016	lectures	BS42016_5.txt	ACES exam preparation.pptx
#
# Your file Linkage_analysis15.pptx from week 1 matched the following modules/documents:
# 579068	BS42003	week 19	BS42003_18.txt	Linkage_background.pptx
# 34114	BS21002	week 10	BS21002_5.txt	genes inheritance and meiosis handout.pptx
# 23490	BS12001	week 16	BS12001_6.txt	BS12001 Meiosis and Mendel(2).pptx
# 19237	BS42003	week 19	BS42003_17.txt	Linkage&QTL_mapping.pptx
# 11591	BS11001	WEEK 2	BS11001_7.txt	BS11002 Inheritance of traits.pptx
# 3886	BS12001	week 18	BS12001_9.txt	BS12001 Genes and pathways.pptx
# 3116	BS42025	lectures	BS42025_1.txt	Analgesics & Anaesthesia Essay Feb 2016.docx
# 2694	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 2455	BS12001	workshops	BS12001_31.txt	BS12001 Chi Square Primer.pdf
# 2401	ocr_alevel	curriculum	ocr_alevel_34.txt	76358-unit-f214-communication-homeostasis-and-energy-medium-banded.pdf
#
# Your file QTL_mapping15.pptx from week 1 matched the following modules/documents:
# 25974	BS32008	week 23	BS32008_23.txt	BS32008 Lec_3_AJF.pptx
# 25591	BS42003	week 19	BS42003_17.txt	Linkage&QTL_mapping.pptx
# 23891	BS32008	week 24	BS32008_30.txt	BS32008 Lec_19_AJF.pptx
# 17885	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 12693	BS42003	week 19	BS42003_19.txt	Prashar_et_al_Tuber%20shape%20TAG2014.pdf
# 11105	BS32008	week 24	BS32008_28.txt	BS32008 Lec_17_AJF.pptx
# 10625	BS42005	lectures	BS42005_34.txt	Zamir 2006.pdf
# 9864	BS42003	week 19	BS42003_15.txt	association mapping(1).pptx
# 8467	BS42003	week 19	BS42003_18.txt	Linkage_background.pptx
# 8097	BS42005	assessments	BS42005_2.txt	BS42005 Tutorial 5 2016.docx
#
# Your file BI31005_Gen_L02_AJF(2).pptx from week 1 matched the following modules/documents:
# 106164	BS32008	week 20	BS32008_7.txt	Lecture 4 - 2016(2).pptx
# 8001	BS32011	project 2	BS32011_7.txt	Mapping Tn_15_16.pptx
# 6344	BS21002	week 3	BS21002_12.txt	BS21002-DNA replication and repair.pptx
# 4367	BS31006	week 10	BS31006_6.txt	BI31006 GS DNA Replication I+II VLE 2015.pptx
# 3626	BS32011	project 2	BS32011_6.txt	BS32011 A2 Microbial Cell Biology 2015-16.pdf
# 2911	BS32008	assessments	BS32008_1.txt	BS32008 Final 2015.docx
# 2631	BS32011	general	BS32011_2.txt	BS32011 module handbook 1516.pdf
# 2465	BS42018	lectures	BS42018_12.txt	synaptic plasticity 2015 A final.pptx
# 2289	BS22003	workshops	BS22003_14.txt	BS22003 Restriction enzymes.pptx
# 1958	BS42023	lectures	BS42023_8.txt	Head injury year 2016.pptx
#
# Your file BI31005_Gen_L01_AJF(1).pptx from week 1 matched the following modules/documents:
# 4293	BS21002	week 3	BS21002_10.txt	advanced-chemistryprize2015.pdf
# 3950	BS42010	lectures	BS42010_16.txt	BS31006_SR_L24-25.pptx
# 3950	BS31006	week 11	BS31006_12.txt	Molecular and Genetic basis of cancer(2).pptx
# 3229	BS42010	lectures	BS42010_12.txt	BS31006_L7_MJRS.pptx
# 3102	BS21002	week 9	BS21002_20.txt	BS21001_JZ_When it goes wrong 1 2015-16(1).pptx
# 3079	BS31006	week 7	BS31006_18.txt	BS31006 Prokar transcription_JZ 2015-16.pptx
# 3060	BS42014	lectures	BS42014_10.txt	BS42014 Lecture 10B.pptx
# 3022	BS42010	lectures	BS42010_14.txt	BS31006_L9_MJRS_nomovie.pptx
# 2749	BS42014	lectures	BS42014_8.txt	BS42014 HSH 5(2).pptx
# 2554	BS21002	week 8	BS21002_19.txt	BS21002_JZ_Translation 2015-16 nomovie(1).pptx
#
# Your file C. elegans Screens jorgenson 2002.pdf from week 2 matched the following modules/documents:
# 6975	BS42008	lectures	BS42008_25.txt	Nat Rev Mol Cell Biol 2008 Gönczy.pdf
# 6767	BS32005	week 21	BS32005_7.txt	Lecture4_Modelorganisms+notes.pptx
# 5953	BS42008	lectures	BS42008_15.txt	Developmental Cell 2007 Goldstein.pdf
# 4734	BS42010	lectures	BS42010_20.txt	Freidberg.pdf
# 4184	BS32004	week 15	BS32004_8.txt	nrmicro1096.pdf
# 4121	BS42023	lectures	BS42023_5.txt	Citron.pdf
# 3398	BS31013	week 3	BS31013_23.txt	Neurotransmitter release.pptx
# 3205	BS31006	week 11	BS31006_11.txt	GRE_APOPTOSIS_Lecture-2.pptx
# 2224	BS42008	lectures	BS42008_23.txt	Lecture 9 BS42008 -2016.pptx
# 2169	BS42008	lectures	BS42008_27.txt	Nature 2009 Siller.pdf
#
# Your file Platerk.quantitative trait mapping.pdf from week 2 matched the following modules/documents:
# 11104	BS32011	project 3	BS32011_18.txt	protein production and purification.pdf
# 10020	BS31016	workshops	BS31016_17.txt	R_workshop2(1)(1)(1).pdf
# 10020	BS31016	workshops	BS31016_18.txt	R_workshop3(1)(1).pdf
# 4527	BS42019	lectures	BS42019_3.txt	Bourque et al Am J Physiol 2011(1).pdf
# 3829	BS42019	lectures	BS42019_31.txt	Roses Nature Review 2000.pdf
# 2489	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 2303	BS42020	lectures	BS42020_31.txt	PharmaNeuroTWO.pptx
# 1638	BS31004	week 11	BS31004_6.txt	SynBio_Review.pdf
# 1503	BS42015	workshops	BS42015_27.txt	Thomson (AmJPhysiol2007)(1).pdf
# 1494	BS32028	week 18	BS32028_23.txt	SHormuzdiNuclearReceptors.pptx
#
# Your file worm breeding for dummies.pdf from week 2 matched the following modules/documents:
# 2667	BS42003	week 19	BS42003_18.txt	Linkage_background.pptx
# 2554	BS42005	lectures	BS42005_15.txt	L4_Plant-Nematode-Int_012015_SEVDA.pptx
# 1930	BS42005	lectures	BS42005_10.txt	Ingo Tutorial BS42005 2016.pptx
# 1733	BS42016	lectures	BS42016_5.txt	ACES exam preparation.pptx
# 1688	BS42018	lectures	BS42018_6.txt	2014_Gouzer et al_BDZ stabilization of GABA-A Rs.pdf
# 1641	BS42019	lectures	BS42019_31.txt	Roses Nature Review 2000.pdf
# 1545	BS32011	project 2	BS32011_6.txt	BS32011 A2 Microbial Cell Biology 2015-16.pdf
# 1462	BS21002	week 10	BS21002_5.txt	genes inheritance and meiosis handout.pptx
# 1397	BS42003	week 19	BS42003_17.txt	Linkage&QTL_mapping.pptx
# 1309	BS32008	week 20	BS32008_9.txt	Lecture 6- 2016(1).pptx
#
# Your file LS4054.Gartner.2015.Final.upload.pdf from week 2 matched the following modules/documents:
# 8962	BS32005	week 22	BS32005_12.txt	Dev_Bio_Lecture_BS32005_2016-JJ.pptx
# 7383	BS32022	week 17	BS32022_7.txt	Brain patterning BS32022 VLE.pptx
# 5354	BS42005	lectures	BS42005_18.txt	Lecture 11 Year 4 McKim.pptx
# 4379	BS21002	week 7	BS21002_16.txt	BS21002_JZ_Diff gene express 2015-16(1).pptx
# 3996	BS11001	WEEK 2	BS11001_6.txt	BS11002 Fidelity of information.pptx
# 3368	BS31006	week 11	BS31006_10.txt	Anton Gartner_GRE_lectures_DNA_repair.pptx
# 2960	BS12003	workshops	BS12003_8.txt	BS12003 Protein expression workshop.pptx
# 2843	BS42010	lectures	BS42010_8.txt	BS31006_AG_L17-18.pptx
# 2793	BS32005	week 21	BS32005_7.txt	Lecture4_Modelorganisms+notes.pptx
# 2750	BS42008	lectures	BS42008_25.txt	Nat Rev Mol Cell Biol 2008 Gönczy.pdf
#
# Your file 2008_NatRevGenet_9_554(1).pdf from week 2 matched the following modules/documents:
# 4906	BS42008	lectures	BS42008_25.txt	Nat Rev Mol Cell Biol 2008 Gönczy.pdf
# 2873	BS42008	lectures	BS42008_27.txt	Nature 2009 Siller.pdf
# 2802	BS42008	lectures	BS42008_15.txt	Developmental Cell 2007 Goldstein.pdf
# 2324	BS32003	week 22	BS32003_15.txt	Session 3 2nd set.pptx
# 2230	BS32008	week 20	BS32008_9.txt	Lecture 6- 2016(1).pptx
# 2201	BS32020	week 21	BS32020_1.txt	BS32020 Lecture 1 Introduction to the Module & Structure of Epithelium(1).pptx
# 2147	BS42010	lectures	BS42010_15.txt	BS31006_SR_L19-20.pptx
# 2147	BS31006	week 9	BS31006_27.txt	RNA lectures.pptx
# 2078	BS32028	week 17	BS32028_13.txt	Third year 2016. Opioid receptors 2 Objectives.pdf
# 1995	BS32003	week 22	BS32003_12.txt	introduction to nuclear receptors.pptx
#
# Your file BI31005_Gen_L14_AJF.pptx from week 2 matched the following modules/documents:
# 26166	BS32008	week 20	BS32008_7.txt	Lecture 4 - 2016(2).pptx
# 12158	BS12001	week 16	BS12001_5.txt	BS12001 Chromosome structure(1).pptx
# 9115	BS21002	week 2	BS21002_7.txt	DNA and Genome structure.pptx
# 5537	BS42025	lectures	BS42025_4.txt	BSc Hons Slides-2 _Feb 2016_ .pptx
# 4106	BS42021	lectures	BS42021_29.txt	WF H&C 3 Action potential & SA node(1).pptx
# 3397	BS21002	week 7	BS21002_17.txt	BS21002_JZ_Transc reg 3 Epig 2015-16.pptx
# 3187	BS21002	week 3	BS21002_12.txt	BS21002-DNA replication and repair.pptx
# 3091	BS21002	week 3	BS21002_13.txt	BS21002-DNA replication.pptx
# 2833	BS32008	assessments	BS32008_1.txt	BS32008 Final 2015.docx
# 2739	BS11001	WEEK 11	BS11001_5.txt	BS11001_LTEY_DZB_molecular_evolution(4).pptx
#
# Your file BI31005_Gen_L16_AJF.pptx from week 2 matched the following modules/documents:
# 55359	BS32008	week 20	BS32008_6.txt	Lecture 3 - 2016.pptx
# 12415	BS11001	WEEK 7	BS11001_14.txt	BS11001_LTEY_DZB_modesofspeciation.pptx
# 7743	BS32027	workshops	BS32027_23.txt	Krieger 2009 (single v multiple sets).pdf
# 6777	BS32027	workshops	BS32027_24.txt	Krieger 2010 (single v mutliple sets).pdf
# 5649	BS32008	week 23	BS32008_21.txt	BS32008 Lec_1_AJF.pptx
# 5627	BS32008	week 24	BS32008_28.txt	BS32008 Lec_17_AJF.pptx
# 5135	BS21002	week 10	BS21002_5.txt	genes inheritance and meiosis handout.pptx
# 3716	BS32008	assessments	BS32008_3.txt	Tutorial 1 Andy Flavell.docx
# 3479	BS42005	lectures	BS42005_34.txt	Zamir 2006.pdf
# 2959	BS42005	lectures	BS42005_5.txt	BS42005 Lec_2016_Hybrid_AJF.pptx
#
# Your file BI31005_Gen_L15_AJF.pptx from week 2 matched the following modules/documents:
# 9149	BS32008	week 20	BS32008_7.txt	Lecture 4 - 2016(2).pptx
# 8137	BS32008	week 20	BS32008_6.txt	Lecture 3 - 2016.pptx
# 3816	BS32009	week 24	BS32009_21.txt	3rd year PID 2.pptx
# 3052	BS31006	week 7	BS31006_19.txt	BS31006Lecture1+2Cowling.pptx
# 2976	BS32008	assessments	BS32008_1.txt	BS32008 Final 2015.docx
# 2915	BS32009	week 23	BS32009_16.txt	BS32009 2016 Cantrell Lymphocyte development.pptx
# 2503	BS21002	week 3	BS21002_12.txt	BS21002-DNA replication and repair.pptx
# 2347	BS42005	lectures	BS42005_17.txt	Lecture 10 Year 4 McKim(1).pptx
# 2092	BS12003	workshops	BS12003_4.txt	BS12003 Protein Expression follow-up workshop INCL ANSWERS.pptx
# 2002	BS32005	week 21	BS32005_7.txt	Lecture4_Modelorganisms+notes.pptx
#
# Your file bb_GGS_plant models.pptx from week 3 matched the following modules/documents:
# 62918	BS42005	lectures	BS42005_31.txt	Simpson Honours 2015 flowering part one(1).pptx
# 42808	BS42005	lectures	BS42005_25.txt	nrg3291[2] copy.pdf
# 34618	BS32008	week 22	BS32008_14.txt	Lecture 11 PH.pptx
# 26810	BS42005	lectures	BS42005_32.txt	Simpson Honours 2015 flowering part two.pptx
# 7138	BS42005	lectures	BS42005_7.txt	comadran - CEN.pdf
# 6813	BS42005	lectures	BS42005_30.txt	seasonal flowering - what's new.pdf
# 6466	BS32008	week 22	BS32008_18.txt	McKim Lecture C2 9March 2016(1).pptx
# 6371	BS32008	week 20	BS32008_4.txt	Lecture 1 compressed.pptx
# 6190	BS32008	week 21	BS32008_10.txt	McKim Lecture 9 Monday 2016.pptx
# 4288	BS32008	week 22	BS32008_19.txt	Piers hemsley BS32008 lecture 11 Text for animations.pdf
#
# Your file Animal_Genetics_Lecture_2013.pdf from week 3 matched the following modules/documents:
# 10251	BS32005	week 22	BS32005_12.txt	Dev_Bio_Lecture_BS32005_2016-JJ.pptx
# 7432	BS32022	week 17	BS32022_7.txt	Brain patterning BS32022 VLE.pptx
# 5295	BS21002	week 7	BS21002_16.txt	BS21002_JZ_Diff gene express 2015-16(1).pptx
# 4513	BS32005	assessments	BS32005_3.txt	Multiple choice and SAQ  for Formative assessment BS32005 2015.docx
# 3867	BS42018	lectures	BS42018_13.txt	Synaptic Plasticity 2015 B final.pptx
# 3045	BS11001	WEEK 2	BS11001_6.txt	BS11002 Fidelity of information.pptx
# 2740	BS32005	week 22	BS32005_11.txt	Developmental Biology L10 KGS.pptx
# 2185	BS32005	week 23	BS32005_15.txt	Developmental Biology L12 KGS VLE.pptx
# 1979	ocr_alevel	skills	ocr_alevel_58.txt	258591-the-ocr-guide-to-problem-solving.pdf
# 1814	BS32005	week 21	BS32005_7.txt	Lecture4_Modelorganisms+notes.pptx
#
# Your file BS31005_D3-1.pptx from week 3 matched the following modules/documents:
# 9633	BS11002	week 4	BS11002_15.txt	L1 Guest lecture_JAP.pptx
# 8582	BS21002	week 2	BS21002_7.txt	DNA and Genome structure.pptx
# 5998	BS32005	week 23	BS32005_19.txt	Stem Cells I_Stavridis_edit.pptx
# 5148	BS21002	week 9	BS21002_22.txt	Manipulating DNA.pptx
# 4495	BS42020	lectures	BS42020_8.txt	BS42020 Chemical Stress Tg models March 2016.pptx
# 4089	BS42015	lectures	BS42015_6.txt	BS42015_DGH_lecture_3-4.pptx
# 3549	BS42008	lectures	BS42008_8.txt	BS24008_Lecture_4_01_02_2016.pdf
# 2728	BS32006	week 17	BS32006_20.txt	BS32006_10CMacK_GproteinsGEFs GAPs 2016.pptx
# 2701	BS32006	week 17	BS32006_22.txt	GCPR1f(n)-1.pptx
# 2280	BS42020	lectures	BS42020_5.txt	Bisphenol A alternatives.pdf
#
# Your file BB_GGS_floral organ.pptx from week 3 matched the following modules/documents:
# 44620	BS32008	week 22	BS32008_15.txt	Lecture 12 PH(1).pptx
# 8776	BS32008	week 22	BS32008_12.txt	Bonus slides about CLAVATA and WUSCHEL 2016.pptx
# 8564	BS42005	lectures	BS42005_17.txt	Lecture 10 Year 4 McKim(1).pptx
# 6789	BS11003	general	BS11003_1.txt	BS11003 Practical Module Handbook 1516.docx
# 6409	BS42005	lectures	BS42005_25.txt	nrg3291[2] copy.pdf
# 4771	BS42009	lectures	BS42009_6.txt	aMMB_Lecture_2_2016.pptx
# 3641	BS32008	week 21	BS32008_10.txt	McKim Lecture 9 Monday 2016.pptx
# 3406	BS32005	week 22	BS32005_12.txt	Dev_Bio_Lecture_BS32005_2016-JJ.pptx
# 2846	BS32008	week 20	BS32008_4.txt	Lecture 1 compressed.pptx
# 2574	BS42018	lectures	BS42018_11.txt	Protein trafficking (Connolly).pptx
#
# Your file Sargent_Genomics_Level3_15_FINAL.pptx from week 4 matched the following modules/documents:
# 290949	BS32004	week 17	BS32004_19.txt	Lecture_3_16_new.pptx
# 13349	BS42009	lectures	BS42009_33.txt	SJCLecture2.pptx
# 7427	BS42009	lectures	BS42009_32.txt	SJCLecture1.pptx
# 3374	BS32004	week 15	BS32004_3.txt	BS2004TPL1withnotes.pptx
# 2703	BS31004	week 10	BS31004_1.txt	Adhesion_Nathke_2015_nov.pdf
# 2448	BS32004	week 15	BS32004_6.txt	Microbial Olympics nrmicro2837.pdf
# 2367	BS22002	week 21	BS22002_19.txt	GMGadd%20Microbial%20Diversity%201st%20Lecture%2026.02.15.pptx
# 2283	BS12003	workshops	BS12003_13.txt	prot_purification_tutorial.pdf
# 2109	BS42009	lectures	BS42009_29.txt	Session I - Slides.pdf
# 1853	BS31004	week 9	BS31004_31.txt	L7 Cilia, flagella and Mitosis updated.pptx
#
# Your file 2014.Gartner.genetics.genomics.short.pptx from week 4 matched the following modules/documents:
# 6745	BS31006	week 11	BS31006_10.txt	Anton Gartner_GRE_lectures_DNA_repair.pptx
# 5872	BS42010	lectures	BS42010_8.txt	BS31006_AG_L17-18.pptx
# 5286	BS21002	week 1	BS21002_3.txt	Lecture1 handout(3).pptx
# 4741	BS31006	week 11	BS31006_9.txt	Anton Gartner.GRE.lectures.repair.final.2015.pptx
# 4253	BS31006	week 11	BS31006_11.txt	GRE_APOPTOSIS_Lecture-2.pptx
# 3780	BS32008	week 24	BS32008_28.txt	BS32008 Lec_17_AJF.pptx
# 2958	BS32008	week 20	BS32008_9.txt	Lecture 6- 2016(1).pptx
# 2606	BS21002	week 8	BS21002_19.txt	BS21002_JZ_Translation 2015-16 nomovie(1).pptx
# 2521	BS32008	week 23	BS32008_21.txt	BS32008 Lec_1_AJF.pptx
# 2082	BS32027	workshops	BS32027_22.txt	ISE Static Stretching Handout.pdf
#
# Your file BI31005_L17-18_AJF.pptx from week 4 matched the following modules/documents:
# 19170	BS32008	week 20	BS32008_7.txt	Lecture 4 - 2016(2).pptx
# 11880	BS21002	week 2	BS21002_8.txt	DNA and sequencing(2).pptx
# 5114	BS31006	week 8	BS31006_22.txt	RNA Processing Lecture 1.pptx
# 5114	BS42010	lectures	BS42010_9.txt	BS31006_AIL_L4.pptx
# 4604	BS22002	week 22	BS22002_20.txt	DMAM Genomes.pptx
# 2879	BS42021	lectures	BS42021_23.txt	Reading list H&C.docx
# 2690	BS11001	WEEK 11	BS11001_5.txt	BS11001_LTEY_DZB_molecular_evolution(4).pptx
# 2103	BS31006	week 8	BS31006_23.txt	RNA Processing Lecture 2-2.pptx
# 2103	BS42010	lectures	BS42010_10.txt	BS31006_AIL_L5.pptx
# 1911	BS31006	week 9	BS31006_28.txt	RNA Processing Lecture 3-2.pptx
#
# Your file Kaper2004_pathogenicEcoli.pdf from week 4 matched the following modules/documents:
# 25583	BS32004	week 15	BS32004_4.txt	BS2004TPL2-3withnotes.pptx
# 20661	BS42009	lectures	BS42009_17.txt	Cornelis2006NRM.pdf
# 20224	BS32004	week 15	BS32004_3.txt	BS2004TPL1withnotes.pptx
# 16594	BS42009	lectures	BS42009_19.txt	Curtis et al., 2014.pdf
# 16495	BS42009	lectures	BS42009_20.txt	Flaugnatti et al 2015 Molecular Microbiology.pdf
# 16408	BS32020	week 24	BS32020_18.txt	Water balance in the G.I. tract_JAP_2016.pptx
# 9688	BS42024	workshops	BS42024_30.txt	RhoGTPasesAndPlasticity.pdf
# 8183	BS42006	week 17	BS42006_8.txt	Glycoimmunology 1(for BB).pptx
# 8053	BS42021	lectures	BS42021_25.txt	Stretch & Ca release.pdf
# 5687	BS22002	week 22	BS22002_21.txt	Microbial genomics.pptx
#
# Your file SietzBlokesch2012.pdf from week 4 matched the following modules/documents:
# 12332	BS42009	lectures	BS42009_15.txt	BS42009 Session I - Literature covered .pdf
# 6770	BS32004	week 16	BS32004_9.txt	BS32004TPL3-4NOTESlatest.pptx
# 5266	BS42009	lectures	BS42009_28.txt	Sargent_AMP_REVIEW.pdf
# 5174	BS11001	WEEK 1	BS11001_3.txt	BS11002 Intro to genetics(1).pptx
# 4922	BS32004	week 16	BS32004_12.txt	Sargent_Lecture_1_16.pptx
# 3416	BS11002	workshops	BS11002_27.txt	BS11002 Woese workshop - Evolution of cells VLE.pptx
# 3363	BS42009	lectures	BS42009_34.txt	SJCLecture3.pptx
# 3217	BS42009	lectures	BS42009_33.txt	SJCLecture2.pptx
# 3073	BS42009	lectures	BS42009_13.txt	BS42009 Lecture 1 information.docx
# 3028	BS11002	workshops	BS11002_29.txt	On the evolution of cells.html
#
# Your file bb_GGS_plant models(1).pptx from week 4 matched the following modules/documents:
# 62918	BS42005	lectures	BS42005_31.txt	Simpson Honours 2015 flowering part one(1).pptx
# 42808	BS42005	lectures	BS42005_25.txt	nrg3291[2] copy.pdf
# 34618	BS32008	week 22	BS32008_14.txt	Lecture 11 PH.pptx
# 26810	BS42005	lectures	BS42005_32.txt	Simpson Honours 2015 flowering part two.pptx
# 7138	BS42005	lectures	BS42005_7.txt	comadran - CEN.pdf
# 6813	BS42005	lectures	BS42005_30.txt	seasonal flowering - what's new.pdf
# 6466	BS32008	week 22	BS32008_18.txt	McKim Lecture C2 9March 2016(1).pptx
# 6371	BS32008	week 20	BS32008_4.txt	Lecture 1 compressed.pptx
# 6190	BS32008	week 21	BS32008_10.txt	McKim Lecture 9 Monday 2016.pptx
# 4288	BS32008	week 22	BS32008_19.txt	Piers hemsley BS32008 lecture 11 Text for animations.pdf
#
# Your file GGS_floral organ.pptx from week 4 matched the following modules/documents:
# 44620	BS32008	week 22	BS32008_15.txt	Lecture 12 PH(1).pptx
# 8776	BS32008	week 22	BS32008_12.txt	Bonus slides about CLAVATA and WUSCHEL 2016.pptx
# 8564	BS42005	lectures	BS42005_17.txt	Lecture 10 Year 4 McKim(1).pptx
# 6789	BS11003	general	BS11003_1.txt	BS11003 Practical Module Handbook 1516.docx
# 6409	BS42005	lectures	BS42005_25.txt	nrg3291[2] copy.pdf
# 4771	BS42009	lectures	BS42009_6.txt	aMMB_Lecture_2_2016.pptx
# 3641	BS32008	week 21	BS32008_10.txt	McKim Lecture 9 Monday 2016.pptx
# 3406	BS32005	week 22	BS32005_12.txt	Dev_Bio_Lecture_BS32005_2016-JJ.pptx
# 2846	BS32008	week 20	BS32008_4.txt	Lecture 1 compressed.pptx
# 2574	BS42018	lectures	BS42018_11.txt	Protein trafficking (Connolly).pptx
#
# Your file BS31005_Evolution_of_DNA.pptx from week 5 matched the following modules/documents:
# 8192	BS32011	project 3	BS32011_13.txt	Enzyme kinetics BS32011 A3 JZ 2015-16 for VLE.pptx
# 5468	BS11001	WEEK 7	BS11001_15.txt	BS11001_Pop genetics(1).pptx
# 5223	BS21002	week 4	BS21002_14.txt	BS21002_JZ_Transcription 1&2 2015-16.pptx
# 5218	BS11001	WEEK 8	BS11001_16.txt	BS11001_Pop genetics.pptx
# 4892	BS42003	week 16	BS42003_8.txt	Perelman et al 2011 journal.pgen.1001342.pdf
# 4580	BS11001	WEEK 10	BS11001_4.txt	BS11002_DZB_EvolutionI&II(1).pptx
# 4362	BS11001	WEEK 9	BS11001_17.txt	BS11001_DZB_EvolutionI II III.pptx
# 3751	BS11001	WEEK 2	BS11001_6.txt	BS11002 Fidelity of information.pptx
# 3391	aqa_alevel	curriculum	aqa_alevel_25.txt	Ratio Worksheet.docx
# 2259	BS11001	WEEK 4	BS11001_10.txt	BS11001_DZB_Sex&Sexdetermination(1).pptx
#
# Your file BS31005_Population_genetics_I&II.pptx from week 5 matched the following modules/documents:
# 65088	BS42003	week 16	BS42003_5.txt	BS42003_Population_genomics.pptx
# 64774	BS11001	WEEK 8	BS11001_16.txt	BS11001_Pop genetics.pptx
# 64607	BS11001	WEEK 7	BS11001_15.txt	BS11001_Pop genetics(1).pptx
# 7273	BS11001	general	BS11001_1.txt	BS11001 handbook.docx
# 6373	BS42003	week 16	BS42003_7.txt	Hoffman et al 2014 PNAS.pdf
# 6040	BS11001	WEEK 2	BS11001_6.txt	BS11002 Fidelity of information.pptx
# 3644	BS42003	week 16	BS42003_3.txt	1-s2.0-S0169534714002511-main.pdf
# 3448	BS11001	WEEK 11	BS11001_5.txt	BS11001_LTEY_DZB_molecular_evolution(4).pptx
# 2319	BS21002	week 11	BS21002_6.txt	BS21002SummaryLecture.pptx
# 2275	BS32004	week 15	BS32004_6.txt	Microbial Olympics nrmicro2837.pdf
#
# Your file BS31005_phylogenetics.pptx from week 5 matched the following modules/documents:
# 13425	BS11001	WEEK 9	BS11001_17.txt	BS11001_DZB_EvolutionI II III.pptx
# 9117	BS11001	WEEK 10	BS11001_4.txt	BS11002_DZB_EvolutionI&II(1).pptx
# 6489	BS42003	week 16	BS42003_5.txt	BS42003_Population_genomics.pptx
# 6376	BS42003	week 16	BS42003_8.txt	Perelman et al 2011 journal.pgen.1001342.pdf
# 3420	BS42003	week 16	BS42003_3.txt	1-s2.0-S0169534714002511-main.pdf
# 3291	BS11001	WEEK 7	BS11001_15.txt	BS11001_Pop genetics(1).pptx
# 3141	BS11001	WEEK 8	BS11001_16.txt	BS11001_Pop genetics.pptx
# 2975	BS21004	workshops	BS21004_12.txt	Introduction to PDP for Level 2 students 1516.pptx
# 2755	BS11002	workshops	BS11002_27.txt	BS11002 Woese workshop - Evolution of cells VLE.pptx
# 2538	BS21001	week 3	BS21001_9.txt	BS21001_stats_5_pops_samples.pptx
#
# Your file Nat Biotechnol 2012 Abe copy.pdf from workshops matched the following modules/documents:
# 5366	BS42005	lectures	BS42005_7.txt	comadran - CEN.pdf
# 4721	BS42023	lectures	BS42023_6.txt	HaasNatMed2010.pdf
# 3245	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 3057	BS42003	week 19	BS42003_21.txt	Yan_Maize_CrtRB1_ng.551.pdf
# 3053	BS32010	week 21	BS32010_7.txt	IntroductionToNGS2016_practical.pptx
# 2786	BS32010	week 21	BS32010_6.txt	IntroductionToNGS2016_lecture(1).pptx
# 2384	BS42005	lectures	BS42005_34.txt	Zamir 2006.pdf
# 1931	BS42005	lectures	BS42005_5.txt	BS42005 Lec_2016_Hybrid_AJF.pptx
# 1731	BS42005	lectures	BS42005_10.txt	Ingo Tutorial BS42005 2016.pptx
# 1649	BS42005	lectures	BS42005_18.txt	Lecture 11 Year 4 McKim.pptx
#
# Your file Gene_editing_summary.docx from workshops matched the following modules/documents:
# 8587	BS42005	assessments	BS42005_2.txt	BS42005 Tutorial 5 2016.docx
# 6013	BS32008	week 24	BS32008_28.txt	BS32008 Lec_17_AJF.pptx
# 5804	BS32004	week 17	BS32004_18.txt	GMG Mycology 2 rev 2015 FINAL(1).pdf
# 4482	BS32008	week 23	BS32008_21.txt	BS32008 Lec_1_AJF.pptx
# 2962	BS32005	week 23	BS32005_19.txt	Stem Cells I_Stavridis_edit.pptx
# 2501	BS21004	general	BS21004_1.txt	BS21004 Module Handbook 1516.docx
# 2334	BS42005	lectures	BS42005_35.txt	Zheng et al 2014 RXLR effectors suppressing early flg22 immune responses.pdf
# 2211	BS32008	week 24	BS32008_31.txt	Lec21(1).pptx
# 2113	BS42005	lectures	BS42005_24.txt	Lecture 5 2016 Level 4 .pptx
# 2083	BS32008	week 20	BS32008_9.txt	Lecture 6- 2016(1).pptx
#
# Your file Essay feedback Sheet.docx from workshops matched the following modules/documents:
# 79073	BS42022	workshops	BS42022_48.txt	BS42022 - Sample Past Exam Questions.pdf
# 7747	BS42015	lectures	BS42015_4.txt	BS42015 Oxygen Uptake and Utilization Study Guide.docx
# 5687	BS32012	general	BS32012_2.txt	BS32012 Assessment Guidance.pdf
# 5624	BS42003	assessments	BS42003_1.txt	BS42003 Advanced Bioinformatics grading criteria 2016.pdf
# 3690	aqa_alevel	assessment	aqa_alevel_1.txt	AQA _ AS and A-level _ Biology _ Practical assessment.html
# 3571	BS31004	week 11	BS31004_7.txt	Systems Biology I temporal networks.pptx
# 3311	BS31004	week 7	BS31004_14.txt	Systems Biology I temporal networks_2014.pptx
# 3188	BS32011	project 3	BS32011_17.txt	Presentation on A3 reports JZ 2015-16(3).pptx
# 1806	BS42015	workshops	BS42015_24.txt	Paper Presentation Guidelines.docx
# 1684	BS42013	workshops	BS42013_26.txt	Paper Presentation Guidelines(1).docx
#
# Your file Goldstein.cas9 copy.pdf from workshops matched the following modules/documents:
# 6366	BS42020	lectures	BS42020_8.txt	BS42020 Chemical Stress Tg models March 2016.pptx
# 2864	BS42010	lectures	BS42010_15.txt	BS31006_SR_L19-20.pptx
# 2864	BS31006	week 9	BS31006_27.txt	RNA lectures.pptx
# 1656	BS21002	general	BS21002_1.txt	BS21002 The Gene and the Cell Handbook 2015.docx
# 1264	BS42008	lectures	BS42008_15.txt	Developmental Cell 2007 Goldstein.pdf
# 1203	BS32012	project 2	BS32012_8.txt	BS32012 B2 Synthetic Biology 2015-16.pdf
# 1054	BS42014	lectures	BS42014_13.txt	Diabetes-2008-McCrimmon-444-50.pdf
# 1037	BS31004	week 11	BS31004_3.txt	Good_SynBio_REview.pdf
# 846	BS42021	workshops	BS42021_35.txt	Reilly FASEB J 2015.pdf
# 761	BS22003	workshops	BS22003_14.txt	BS22003 Restriction enzymes.pptx
#
# Your file Genome_editing_review.docx from workshops matched the following modules/documents:
# 9309	BS32005	week 23	BS32005_19.txt	Stem Cells I_Stavridis_edit.pptx
# 3960	BS42003	week 19	BS42003_15.txt	association mapping(1).pptx
# 3098	BS42005	lectures	BS42005_24.txt	Lecture 5 2016 Level 4 .pptx
# 2233	BS42010	lectures	BS42010_15.txt	BS31006_SR_L19-20.pptx
# 2233	BS31006	week 9	BS31006_27.txt	RNA lectures.pptx
# 2198	BS42012	lectures	BS42012_4.txt	BS42012 reading list.pdf
# 2069	BS32024	week 25	BS32024_21.txt	Neuronal dysfunction.pptx
# 1890	BS42012	lectures	BS42012_3.txt	BS42012 reading list v2.docx
# 1886	BS21002	week 9	BS21002_22.txt	Manipulating DNA.pptx
# 1843	BS32008	week 24	BS32008_31.txt	Lec21(1).pptx
#
# Your file nbt.2969 copy.pdf from workshops matched the following modules/documents:
# 6285	BS32008	week 24	BS32008_31.txt	Lec21(1).pptx
# 3708	BS32004	week 17	BS32004_18.txt	GMG Mycology 2 rev 2015 FINAL(1).pdf
# 3386	BS32008	week 20	BS32008_9.txt	Lecture 6- 2016(1).pptx
# 3170	BS42005	lectures	BS42005_7.txt	comadran - CEN.pdf
# 3127	BS42003	week 19	BS42003_21.txt	Yan_Maize_CrtRB1_ng.551.pdf
# 3121	BS42005	lectures	BS42005_35.txt	Zheng et al 2014 RXLR effectors suppressing early flg22 immune responses.pdf
# 2951	BS42005	lectures	BS42005_24.txt	Lecture 5 2016 Level 4 .pptx
# 1972	BS32008	week 20	BS32008_6.txt	Lecture 3 - 2016.pptx
# 1899	BS21004	general	BS21004_1.txt	BS21004 Module Handbook 1516.docx
# 1789	BS21002	week 9	BS21002_20.txt	BS21001_JZ_When it goes wrong 1 2015-16(1).pptx
#
# Your file Plasterk.mapping copy.pdf from workshops matched the following modules/documents:
# 11074	BS32011	project 3	BS32011_18.txt	protein production and purification.pdf
# 4754	BS31016	workshops	BS31016_17.txt	R_workshop2(1)(1)(1).pdf
# 4754	BS31016	workshops	BS31016_18.txt	R_workshop3(1)(1).pdf
# 4508	BS42019	lectures	BS42019_3.txt	Bourque et al Am J Physiol 2011(1).pdf
# 3869	BS42019	lectures	BS42019_31.txt	Roses Nature Review 2000.pdf
# 2479	BS42003	week 19	BS42003_16.txt	collard_mapping review_Euphytica 2005.pdf
# 2294	BS42020	lectures	BS42020_31.txt	PharmaNeuroTWO.pptx
# 2181	BS32012	general	BS32012_6.txt	SLS Level 3 Protocol Manual 20151201.pdf
# 2181	BS32011	general	BS32011_4.txt	SLS Level 3 Protocol Manual 20151201.pdf
# 1792	BS42003	week 19	BS42003_17.txt	Linkage&QTL_mapping.pptx

# %%
corpus.cal_network('ahall4network.csv',minsize=700)

# %%
sorted([k.lower() for k in corpus.fileinfo.keys()])[:20]

# %%
corpus.load_fileinfo('keydata5')
